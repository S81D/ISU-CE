# %%
import scipy as sp
from scipy import stats
from scipy import integrate
from statistics import NormalDist
import numpy  as np
import matplotlib.pyplot as plt

# Load in Data
RT0_IC = np.loadtxt('RT0_IC_data(w Dis updated).dat', dtype = float, delimiter = None)
RT5_IC = np.loadtxt('RT5_IC_data(w Dis updated).dat', dtype = float, delimiter = None)
RT20_IC = np.loadtxt('RT20_IC_data(w Dis updated).dat', dtype = float, delimiter = None)
RT100_IC = np.loadtxt('RT100_IC_data(w Dis updated).dat', dtype = float, delimiter = None)
CT5_IC = np.loadtxt('CT5_IC_data_(w Dis updated).dat', dtype = float, delimiter = None)
CT20_IC = np.loadtxt('CT20_IC_data_(w Dis updated).dat', dtype = float, delimiter = None)
CT100_IC = np.loadtxt('CT100_IC_data_(w Dis updated).dat', dtype = float, delimiter = None)

RT0_PW = np.loadtxt('RT0_PW_data(w Dis updated).dat', dtype = float, delimiter = None)
RT5_PW = np.loadtxt('RT5_PW_data(w Dis updated).dat', dtype = float, delimiter = None)
RT20_PW = np.loadtxt('RT20_PW_data(w Dis updated).dat', dtype = float, delimiter = None)
RT100_PW = np.loadtxt('RT100_PW_data(w Dis updated).dat', dtype = float, delimiter = None)
CT5_PW = np.loadtxt('CT5_PW_data_(w Dis updated).dat', dtype = float, delimiter = None)
CT20_PW = np.loadtxt('CT20_PW_data_(w Dis updated).dat', dtype = float, delimiter = None)
CT100_PW = np.loadtxt('CT100_PW_data_(w Dis updated).dat', dtype = float, delimiter = None)


print('done')
# Out:
# done

# %%
# Statistics on the Distributions

'''Assume Normal Statistics for all PW and IC Distributions'''

# # # # # # # # RT[0] IC and PW # # # # # # # # # # 
print('\n############# RT[0] #############')
norm_RT0_IC = NormalDist.from_samples(RT0_IC)
mean_RT0_IC = norm_RT0_IC.mean; std_RT0_IC = norm_RT0_IC.stdev
mRT0_IC = r'$\mu$' + ' = ' + str(round(mean_RT0_IC,1))
sRT0_IC = r'$\sigma$' + ' = ' + str(round(std_RT0_IC,1))

print('Mean of IC Distribution = ', round(mean_RT0_IC,2))
print('Sigma of IC Distribution = ', round(std_RT0_IC,2))
print('3-Sigma = ',round(3*std_RT0_IC,2),' [',round(mean_RT0_IC - 3*std_RT0_IC,2),
      ':',round(mean_RT0_IC + 3*std_RT0_IC,2), ']')
print('5-Sigma = ', round(5*std_RT0_IC,2),' [',round(mean_RT0_IC - 5*std_RT0_IC,2),
      ':',round(mean_RT0_IC + 5*std_RT0_IC,2), ']')

norm_RT0_PW = NormalDist.from_samples(RT0_PW)
mean_RT0_PW = norm_RT0_PW.mean; std_RT0_PW = norm_RT0_PW.stdev
mRT0_PW = r'$\mu$' + ' = ' + str(round(mean_RT0_PW,2))
sRT0_PW = r'$\sigma$' + ' = ' + str(round(std_RT0_PW,2))

print('Mean of PW Distribution = ', round(mean_RT0_PW,2))
print('Sigma of PW Distribution = ', round(std_RT0_PW,2))
print('3-Sigma = ',round(3*std_RT0_PW,2),' [',round(mean_RT0_PW - 3*std_RT0_PW,2),
      ':',round(mean_RT0_PW + 3*std_RT0_PW,2), ']')
print('5-Sigma = ', round(5*std_RT0_PW,2),' [',round(mean_RT0_PW - 5*std_RT0_PW,2),
      ':',round(mean_RT0_PW + 5*std_RT0_PW,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[5] IC and PW # # # # # # # # # # 
print('\n############# RT[5] #############')
norm_RT5_IC = NormalDist.from_samples(RT5_IC)
mean_RT5_IC = norm_RT5_IC.mean; std_RT5_IC = norm_RT5_IC.stdev
mRT5_IC = r'$\mu$' + ' = ' + str(round(mean_RT5_IC,1))
sRT5_IC = r'$\sigma$' + ' = ' + str(round(std_RT5_IC,1))

print('Mean of IC Distribution = ', round(mean_RT5_IC,2))
print('Sigma of IC Distribution = ', round(std_RT5_IC,2))
print('3-Sigma = ',round(3*std_RT5_IC,2),' [',round(mean_RT5_IC - 3*std_RT5_IC,2),
      ':',round(mean_RT5_IC + 3*std_RT5_IC,2), ']')
print('5-Sigma = ', round(5*std_RT5_IC,2),' [',round(mean_RT5_IC - 5*std_RT5_IC,2),
      ':',round(mean_RT5_IC + 5*std_RT5_IC,2), ']')

norm_RT5_PW = NormalDist.from_samples(RT5_PW)
mean_RT5_PW = norm_RT5_PW.mean; std_RT5_PW = norm_RT5_PW.stdev
mRT5_PW = r'$\mu$' + ' = ' + str(round(mean_RT5_PW,2))
sRT5_PW = r'$\sigma$' + ' = ' + str(round(std_RT5_PW,2))

print('Mean of PW Distribution = ', round(mean_RT5_PW,2))
print('Sigma of PW Distribution = ', round(std_RT5_PW,2))
print('3-Sigma = ',round(3*std_RT5_PW,2),' [',round(mean_RT5_PW - 3*std_RT5_PW,2),
      ':',round(mean_RT5_PW + 3*std_RT5_PW,2), ']')
print('5-Sigma = ', round(5*std_RT5_PW,2),' [',round(mean_RT5_PW - 5*std_RT5_PW,2),
      ':',round(mean_RT5_PW + 5*std_RT5_PW,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[20] IC and PW # # # # # # # # # # 
print('\n############# RT[20] #############')
norm_RT20_IC = NormalDist.from_samples(RT20_IC)
mean_RT20_IC = norm_RT20_IC.mean; std_RT20_IC = norm_RT20_IC.stdev
mRT20_IC = r'$\mu$' + ' = ' + str(round(mean_RT20_IC,1))
sRT20_IC = r'$\sigma$' + ' = ' + str(round(std_RT20_IC,1))

print('Mean of IC Distribution = ', round(mean_RT20_IC,2))
print('Sigma of IC Distribution = ', round(std_RT20_IC,2))
print('3-Sigma = ',round(3*std_RT20_IC,2),' [',round(mean_RT20_IC - 3*std_RT20_IC,2),
      ':',round(mean_RT20_IC + 3*std_RT20_IC,2), ']')
print('5-Sigma = ', round(5*std_RT20_IC,2),' [',round(mean_RT20_IC - 5*std_RT20_IC,2),
      ':',round(mean_RT20_IC + 5*std_RT20_IC,2), ']')

norm_RT20_PW = NormalDist.from_samples(RT20_PW)
mean_RT20_PW = norm_RT20_PW.mean; std_RT20_PW = norm_RT20_PW.stdev
mRT20_PW = r'$\mu$' + ' = ' + str(round(mean_RT20_PW,2))
sRT20_PW = r'$\sigma$' + ' = ' + str(round(std_RT20_PW,2))

print('Mean of PW Distribution = ', round(mean_RT20_PW,2))
print('Sigma of PW Distribution = ', round(std_RT20_PW,2))
print('3-Sigma = ',round(3*std_RT20_PW,2),' [',round(mean_RT20_PW - 3*std_RT20_PW,2),
      ':',round(mean_RT20_PW + 3*std_RT20_PW,2), ']')
print('5-Sigma = ', round(5*std_RT20_PW,2),' [',round(mean_RT20_PW - 5*std_RT20_PW,2),
      ':',round(mean_RT20_PW + 5*std_RT20_PW,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[100] IC and PW # # # # # # # # # # 
print('\n############# RT[100] #############')
norm_RT100_IC = NormalDist.from_samples(RT100_IC)
mean_RT100_IC = norm_RT100_IC.mean; std_RT100_IC = norm_RT100_IC.stdev
mRT100_IC = r'$\mu$' + ' = ' + str(round(mean_RT100_IC,1))
sRT100_IC = r'$\sigma$' + ' = ' + str(round(std_RT100_IC,1))

print('Mean of IC Distribution = ', round(mean_RT100_IC,2))
print('Sigma of IC Distribution = ', round(std_RT100_IC,2))
print('3-Sigma = ',round(3*std_RT100_IC,2),' [',round(mean_RT100_IC - 3*std_RT100_IC,2),
      ':',round(mean_RT100_IC + 3*std_RT100_IC,2), ']')
print('5-Sigma = ', round(5*std_RT100_IC,2),' [',round(mean_RT100_IC - 5*std_RT100_IC,2),
      ':',round(mean_RT100_IC + 5*std_RT100_IC,2), ']')

norm_RT100_PW = NormalDist.from_samples(RT100_PW)
mean_RT100_PW = norm_RT100_PW.mean; std_RT100_PW = norm_RT100_PW.stdev
mRT100_PW = r'$\mu$' + ' = ' + str(round(mean_RT100_PW,2))
sRT100_PW = r'$\sigma$' + ' = ' + str(round(std_RT100_PW,2))

print('Mean of PW Distribution = ', round(mean_RT100_PW,2))
print('Sigma of PW Distribution = ', round(std_RT100_PW,2))
print('3-Sigma = ',round(3*std_RT100_PW,2),' [',round(mean_RT100_PW - 3*std_RT100_PW,2),
      ':',round(mean_RT100_PW + 3*std_RT100_PW,2), ']')
print('5-Sigma = ', round(5*std_RT100_PW,2),' [',round(mean_RT100_PW - 5*std_RT100_PW,2),
      ':',round(mean_RT100_PW + 5*std_RT100_PW,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[5] IC and PW # # # # # # # # # # 
print('\n############# CT[5] #############')
norm_CT5_IC = NormalDist.from_samples(CT5_IC)
mean_CT5_IC = norm_CT5_IC.mean; std_CT5_IC = norm_CT5_IC.stdev
mCT5_IC = r'$\mu$' + ' = ' + str(round(mean_CT5_IC,1))
sCT5_IC = r'$\sigma$' + ' = ' + str(round(std_CT5_IC,1))

print('Mean of IC Distribution = ', round(mean_CT5_IC,2))
print('Sigma of IC Distribution = ', round(std_CT5_IC,2))
print('3-Sigma = ',round(3*std_CT5_IC,2),' [',round(mean_CT5_IC - 3*std_CT5_IC,2),
      ':',round(mean_CT5_IC + 3*std_CT5_IC,2), ']')
print('5-Sigma = ', round(5*std_CT5_IC,2),' [',round(mean_CT5_IC - 5*std_CT5_IC,2),
      ':',round(mean_CT5_IC + 5*std_CT5_IC,2), ']')

norm_CT5_PW = NormalDist.from_samples(CT5_PW)
mean_CT5_PW = norm_CT5_PW.mean; std_CT5_PW = norm_CT5_PW.stdev
mCT5_PW = r'$\mu$' + ' = ' + str(round(mean_CT5_PW,2))
sCT5_PW = r'$\sigma$' + ' = ' + str(round(std_CT5_PW,2))

print('Mean of PW Distribution = ', round(mean_CT5_PW,2))
print('Sigma of PW Distribution = ', round(std_CT5_PW,2))
print('3-Sigma = ',round(3*std_CT5_PW,2),' [',round(mean_CT5_PW - 3*std_CT5_PW,2),
      ':',round(mean_CT5_PW + 3*std_CT5_PW,2), ']')
print('5-Sigma = ', round(5*std_CT5_PW,2),' [',round(mean_CT5_PW - 5*std_CT5_PW,2),
      ':',round(mean_CT5_PW + 5*std_CT5_PW,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[20] IC and PW # # # # # # # # # # 
print('\n############# CT[20] #############')
norm_CT20_IC = NormalDist.from_samples(CT20_IC)
mean_CT20_IC = norm_CT20_IC.mean; std_CT20_IC = norm_CT20_IC.stdev
mCT20_IC = r'$\mu$' + ' = ' + str(round(mean_CT20_IC,1))
sCT20_IC = r'$\sigma$' + ' = ' + str(round(std_CT20_IC,1))

print('Mean of IC Distribution = ', round(mean_CT20_IC,2))
print('Sigma of IC Distribution = ', round(std_CT20_IC,2))
print('3-Sigma = ',round(3*std_CT20_IC,2),' [',round(mean_CT20_IC - 3*std_CT20_IC,2),
      ':',round(mean_CT20_IC + 3*std_CT20_IC,2), ']')
print('5-Sigma = ', round(5*std_CT20_IC,2),' [',round(mean_CT20_IC - 5*std_CT20_IC,2),
      ':',round(mean_CT20_IC + 5*std_CT20_IC,2), ']')

norm_CT20_PW = NormalDist.from_samples(CT20_PW)
mean_CT20_PW = norm_CT20_PW.mean; std_CT20_PW = norm_CT20_PW.stdev
mCT20_PW = r'$\mu$' + ' = ' + str(round(mean_CT20_PW,2))
sCT20_PW = r'$\sigma$' + ' = ' + str(round(std_CT20_PW,2))

print('Mean of PW Distribution = ', round(mean_CT20_PW,2))
print('Sigma of PW Distribution = ', round(std_CT20_PW,2))
print('3-Sigma = ',round(3*std_CT20_PW,2),' [',round(mean_CT20_PW - 3*std_CT20_PW,2),
      ':',round(mean_CT20_PW + 3*std_CT20_PW,2), ']')
print('5-Sigma = ', round(5*std_CT20_PW,2),' [',round(mean_CT20_PW - 5*std_CT20_PW,2),
      ':',round(mean_CT20_PW + 5*std_CT20_PW,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[100] IC and PW # # # # # # # # # # 
print('\n############# CT[100] #############')
norm_CT100_IC = NormalDist.from_samples(CT100_IC)
mean_CT100_IC = norm_CT100_IC.mean; std_CT100_IC = norm_CT100_IC.stdev
mCT100_IC = r'$\mu$' + ' = ' + str(round(mean_CT100_IC,1))
sCT100_IC = r'$\sigma$' + ' = ' + str(round(std_CT100_IC,1))

print('Mean of IC Distribution = ', round(mean_CT100_IC,2))
print('Sigma of IC Distribution = ', round(std_CT100_IC,2))
print('3-Sigma = ',round(3*std_CT100_IC,2),' [',round(mean_CT100_IC - 3*std_CT100_IC,2),
      ':',round(mean_CT100_IC + 3*std_CT100_IC,2), ']')
print('5-Sigma = ', round(5*std_CT100_IC,2),' [',round(mean_CT100_IC - 5*std_CT100_IC,2),
      ':',round(mean_CT100_IC + 5*std_CT100_IC,2), ']')

norm_CT100_PW = NormalDist.from_samples(CT100_PW)
mean_CT100_PW = norm_CT100_PW.mean; std_CT100_PW = norm_CT100_PW.stdev
mCT100_PW = r'$\mu$' + ' = ' + str(round(mean_CT100_PW,2))
sCT100_PW = r'$\sigma$' + ' = ' + str(round(std_CT100_PW,2))

print('Mean of PW Distribution = ', round(mean_CT100_PW,2))
print('Sigma of PW Distribution = ', round(std_CT100_PW,2))
print('3-Sigma = ',round(3*std_CT100_PW,2),' [',round(mean_CT100_PW - 3*std_CT100_PW,2),
      ':',round(mean_CT100_PW + 3*std_CT100_PW,2), ']')
print('5-Sigma = ', round(5*std_CT100_PW,2),' [',round(mean_CT100_PW - 5*std_CT100_PW,2),
      ':',round(mean_CT100_PW + 5*std_CT100_PW,2), ']')


print('\ndone')
# Out:
# ############# RT[0] #############
# Mean of IC Distribution =  79381.05
# Sigma of IC Distribution =  2454.63
# 3-Sigma =  7363.88  [ 72017.17 : 86744.93 ]
# 5-Sigma =  12273.13  [ 67107.92 : 91654.19 ]
# Mean of PW Distribution =  11.95
# Sigma of PW Distribution =  0.18
# 3-Sigma =  0.55  [ 11.4 : 12.5 ]
# 5-Sigma =  0.92  [ 11.03 : 12.86 ]
#
# ############# RT[5] #############
# Mean of IC Distribution =  79059.53
# Sigma of IC Distribution =  2188.05
# 3-Sigma =  6564.14  [ 72495.38 : 85623.67 ]
# 5-Sigma =  10940.23  [ 68119.29 : 89999.76 ]
# Mean of PW Distribution =  11.93
# Sigma of PW Distribution =  0.19
# 3-Sigma =  0.56  [ 11.37 : 12.49 ]
# 5-Sigma =  0.93  [ 11.0 : 12.86 ]
#
# ############# RT[20] #############
# Mean of IC Distribution =  78968.79
# Sigma of IC Distribution =  2224.97
# 3-Sigma =  6674.92  [ 72293.86 : 85643.71 ]
# 5-Sigma =  11124.87  [ 67843.92 : 90093.66 ]
# Mean of PW Distribution =  11.93
# Sigma of PW Distribution =  0.2
# ...

# %% [markdown]
# ## Save to Desktop - Different Picture Format

# %%
##########################################################

# Comparison between RT[100] and CT[100] for Integrated Charge
fig, ax = plt.subplots()
ax.set_title('Integrated Charge Distribution of P3 FE ASIC Pulses | LN2 vs RT | Subrun[20] 1000mV BL',
            fontdict = {'fontsize' : 10})
ax.set_xlabel('Integrated Charge', loc = 'right')

# Ensure identical binning for histograms
c = max(RT100_IC)-min(RT100_IC); d = max(CT100_IC)-min(CT100_IC); ratio = d/c
binsRT100IC = 200; binsCT100IC = int(binsRT100IC*ratio)

# Plot Histograms
ax.hist(RT100_IC, bins = binsRT100IC, histtype = 'step', hatch = '...', stacked = False,
        color = 'darkred', linewidth = 1.5, label = 'RT[100] IC Distribution')
ax.hist(CT100_IC, bins = binsCT100IC, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'navy', linewidth = 1.5, label = 'CT[100] IC Distribution')
plt.xlim([60000,100000])

# Label values of mu and sigma on the plots within a txt box
textstr = '\n'.join(('RT[100]', mRT100_IC, sRT100_IC))
props = dict(boxstyle='round', facecolor='rosybrown', alpha=0.5)
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)
textstr = '\n'.join(('CT[100]', mCT100_IC, sCT100_IC))
props = dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.5)
ax.text(0.05, 0.70, textstr, transform=ax.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)

plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path1 = '../../../../IC [100] RT CT.png'
plt.savefig(path1,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')

plt.show()

##########################################################

# Comparison between RT[100] and CT[100] for Pulse Widths
fig2, ax2 = plt.subplots()
ax2.set_title('FWHM Distribution of P3 FE ASIC Pulses | LN2 vs RT | Subrun[20] 1000mV BL',
             fontdict = {'fontsize' : 10})
ax2.set_xlabel('FWHM', loc = 'right')
e = max(RT100_PW)-min(RT100_PW); f = max(CT100_PW)-min(CT100_PW); ratio_1 = f/e
binsRT100PW = 100; binsCT100PW = int(binsRT100PW*ratio_1)
ax2.hist(RT100_PW, bins = binsRT100PW, histtype = 'step', hatch = '...', stacked = False,
        color = 'tab:red', linewidth = 1.5, label = 'RT[100] PW Distribution')
ax2.hist(CT100_PW, bins = binsCT100PW, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'tab:blue', linewidth = 1.5, label = 'CT[100] PW Distribution')
plt.xlim([8.5,14.5])

# Label values of mu and sigma on the plots within a txt box
textstr = '\n'.join(('RT[100]', mRT100_PW, sRT100_PW))
props = dict(boxstyle='round', facecolor='rosybrown', alpha=0.5)
ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)
textstr = '\n'.join(('CT[100]', mCT100_PW, sCT100_PW))
props = dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.5)
ax2.text(0.05, 0.70, textstr, transform=ax2.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)

plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path2 = '../../../../PW [100] RT CT.png'
plt.savefig(path2,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')
plt.show()

##########################################################

# Comparison between RT[0], RT[5], RT[20], and RT[100] for Pulse Widths
fig3, ax3 = plt.subplots()
ax3.set_title('FWHM of P3 FE ASIC Pulses in RT | Subrun[20] 200mV BL',
             fontdict = {'fontsize' : 10})
ax3.set_xlabel('FWHM', loc = 'right')
g = max(RT5_PW)-min(RT5_PW); h = max(RT0_PW)-min(RT0_PW); hh = max(RT20_PW)-min(RT20_PW); hhh = max(RT100_PW)-min(RT100_PW)
ratio_2 = h/g; ratio_22 = hh/g; ratio_222 = hhh/g
binsRT5PW = 20; binsRT0PW = int(binsRT5PW*ratio_2); binsRT20PW = int(binsRT5PW*ratio_22); binsRT100PW = int(binsRT5PW*ratio_222)
ax3.hist(RT0_PW, bins = binsRT0PW, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'tab:green', linewidth = 1.5, label = 'RT[0] PW Distribution')
ax3.hist(RT5_PW, bins = binsRT5PW, histtype = 'step', hatch = '...', stacked = False,
        color = 'tab:blue', linewidth = 1.5, label = 'RT[5] PW Distribution')
ax3.hist(RT20_PW, bins = binsRT20PW, histtype = 'step', hatch = '///', stacked = False,
        color = 'tab:red', linewidth = 1.5, label = 'RT[20] PW Distribution')
ax3.hist(RT100_PW, bins = binsRT100PW, histtype = 'step', hatch = '---', stacked = False,
        color = 'black', linewidth = 1.5, label = 'RT[100] PW Distribution')
plt.xlim([8.5,14.5])

# Label values of mu and sigma on the plots within a txt box
textstr = '\n'.join(('RT[0]', mRT0_PW, sRT0_PW))
props = dict(boxstyle='round', facecolor='mediumseagreen', alpha=0.5)
ax3.text(0.05, 0.95, textstr, transform=ax3.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('RT[5]', mRT5_PW, sRT5_PW))
props = dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.5)
ax3.text(0.05, 0.75, textstr, transform=ax3.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('RT[20]', mRT20_PW, sRT20_PW))
props = dict(boxstyle='round', facecolor='lightcoral', alpha=0.5)
ax3.text(0.05, 0.55, textstr, transform=ax3.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('RT[100]', mRT100_PW, sRT100_PW))
props = dict(boxstyle='round', facecolor='grey', alpha=0.5)
ax3.text(0.05, 0.35, textstr, transform=ax3.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)


plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path3 = '../../../../PW RT.png'
plt.savefig(path3,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')
plt.show()

##########################################################

# Comparison between RT[0], RT[5], RT[20], and RT[100] for Integrated Charge
fig4, ax4 = plt.subplots()
ax4.set_title('Integrated Charge of P3 FE ASIC Pulses in RT | Subrun[20] 200mV BL',
             fontdict = {'fontsize' : 10})
ax4.set_xlabel('Integrated Charge', loc = 'right')
i = max(RT5_IC)-min(RT5_IC); j = max(RT0_IC)-min(RT0_IC); ratio_3 = j/i; jj = max(RT20_IC)-min(RT20_IC); jjj = max(RT100_IC)-min(RT100_IC)
ratio_33 = jj/i; ratio_333 = jjj/i
binsRT5IC = 30; binsRT0IC = int(binsRT5IC*ratio_3); binsRT20IC = int(binsRT5IC*ratio_33); binsRT100IC = int(binsRT5IC*ratio_333)
ax4.hist(RT0_IC, bins = binsRT0IC, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'tab:green', linewidth = 1.5, label = 'RT[0] IC Distribution')
ax4.hist(RT5_IC, bins = binsRT5IC, histtype = 'step', hatch = '...', stacked = False,
        color = 'tab:red', linewidth = 1.5, label = 'RT[5] IC Distribution')
ax4.hist(RT20_IC, bins = binsRT20IC, histtype = 'step', hatch = '///', stacked = False,
        color = 'tab:blue', linewidth = 1.5, label = 'RT[20] IC Distribution')
ax4.hist(RT100_IC, bins = binsRT100IC, histtype = 'step', hatch = '---', stacked = False,
        color = 'black', linewidth = 1.5, label = 'RT[100] IC Distribution')
plt.xlim([60000,100000])

# Label values of mu and sigma on the plots within a txt box
textstr = '\n'.join(('RT[0]', mRT0_IC, sRT0_IC))
props = dict(boxstyle='round', facecolor='mediumseagreen', alpha=0.5)
ax4.text(0.05, 0.95, textstr, transform=ax4.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('RT[5]', mRT5_IC, sRT5_IC))
props = dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.5)
ax4.text(0.05, 0.75, textstr, transform=ax4.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('RT[20]', mRT20_IC, sRT20_IC))
props = dict(boxstyle='round', facecolor='lightcoral', alpha=0.5)
ax4.text(0.05, 0.55, textstr, transform=ax4.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('RT[100]', mRT100_IC, sRT100_IC))
props = dict(boxstyle='round', facecolor='grey', alpha=0.5)
ax4.text(0.05, 0.35, textstr, transform=ax4.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path4 = '../../../../IC RT.png'
plt.savefig(path4,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')
plt.show()

##########################################################

# Comparison between CT[5], CT[20], and CT[100] for Integrated Charge
fig, ax = plt.subplots()
ax.set_title('Integrated Charge of P3 FE ASIC Pulses in LN2 | Subrun[20] 200mV BL',
            fontdict = {'fontsize' : 10})
ax.set_xlabel('Integrated Charge', loc = 'right')
c = max(CT5_IC)-min(CT5_IC); d = max(CT20_IC)-min(CT20_IC); dd = max(CT100_IC)-min(CT100_IC); ratio = d/c; ratio_100 = dd/c
binsCT5IC = 130; binsCT20IC = int(binsCT5IC*ratio); binsCT100IC = int(binsCT5IC*ratio_100)
ax.hist(CT5_IC, bins = binsCT5IC, histtype = 'step', hatch = '...', stacked = False, 
        color = 'tab:blue', linewidth = 1.5, label = 'CT[5] IC Distribution')
ax.hist(CT20_IC, bins = binsCT20IC, histtype = 'step', hatch = 'xxx', stacked = False, 
        color = 'tab:red', linewidth = 1.5, label = 'CT[20] IC Distribution')
ax.hist(CT100_IC, bins = binsCT100IC, histtype = 'step', hatch = '///', stacked = False, 
        color = 'black', linewidth = 1.5, label = 'CT[100] IC Distribution')
plt.xlim([60000,100000])

# Label values of mu and sigma on the plots within a txt box
textstr = '\n'.join(('CT[5]', mCT5_IC, sCT5_IC))
props = dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.5)
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('CT[20]', mCT20_IC, sCT20_IC))
props = dict(boxstyle='round', facecolor='lightcoral', alpha=0.5)
ax.text(0.05, 0.75, textstr, transform=ax.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('CT[100]', mCT100_IC, sCT100_IC))
props = dict(boxstyle='round', facecolor='grey', alpha=0.5)
ax.text(0.05, 0.55, textstr, transform=ax.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path1 = '../../../../IC CT.png'
plt.savefig(path1,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')

plt.show()

##########################################################

# Comparison between CT[5], CT[20], and CT[100] for Pulse Widths
fig2, ax2 = plt.subplots()
ax2.set_title('FWHM of P3 FE ASIC Pulses in LN2 | Subrun[20] 200mV BL',
             fontdict = {'fontsize' : 10})
ax2.set_xlabel('FWHM', loc = 'right')
e = max(CT5_PW)-min(CT5_PW); f = max(CT20_PW)-min(CT20_PW); ff = max(CT100_PW)-min(CT100_PW); ratio_1 = f/e; ratio_11 = ff/e
binsCT5PW = 85; binsCT20PW = int(binsCT5PW*ratio_1); binsCT100PW = int(binsCT5PW*ratio_11)
ax2.hist(CT5_PW, bins = binsCT5PW, histtype = 'step', hatch = '...', stacked = False,
        color = 'tab:blue', linewidth = 1.5, label = 'CT[5] PW Distribution')
ax2.hist(CT20_PW, bins = binsCT20PW, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'tab:red', linewidth = 1.5, label = 'CT[20] PW Distribution')
ax2.hist(CT100_PW, bins = binsCT100PW, histtype = 'step', hatch = '///', stacked = False,
        color = 'black', linewidth = 1.5, label = 'CT[100] PW Distribution')
plt.xlim([8.5,14.5])

# Label values of mu and sigma on the plots within a txt box
textstr = '\n'.join(('CT[5]', mCT5_PW, sCT5_PW))
props = dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.5)
ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('CT[20]', mCT20_PW, sCT20_PW))
props = dict(boxstyle='round', facecolor='lightcoral', alpha=0.5)
ax2.text(0.05, 0.75, textstr, transform=ax2.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)

textstr = '\n'.join(('CT[100]', mCT100_PW, sCT100_PW))
props = dict(boxstyle='round', facecolor='grey', alpha=0.5)
ax2.text(0.05, 0.55, textstr, transform=ax2.transAxes, fontsize=9,
        verticalalignment='top', bbox=props)


plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path2 = '../../../../PW CT.png'
plt.savefig(path2,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')
plt.show()

###########################################################################

print('\ndone')
# Out:
# done

# %%
# Previous Labels on Plot, in case I decide to go back to this
'''
# Label Mean and sigma (assuming Normal Distribution) on plot
ax.text(.06,0.86,'RT[100]',size = 8,transform = ax.transAxes)
#ax.text(.06,0.82,'Pulse Sampling Success ' + str(round(50*len(RT100_IC)/(50*PS_RT100),2)) + '%',size = 8,transform = ax.transAxes)
ax.text(.06,0.78,mRT100_IC,size = 8,transform = ax.transAxes)
ax.text(.06,0.74,sRT100_IC,size = 8,transform = ax.transAxes)
ax.text(.06,0.66,'CT[100]',size = 8,transform = ax.transAxes)
#ax.text(.06,0.62,'Pulse Sampling Success ' + str(round(50*len(CT100_IC)/(50*PS_CT100),2)) + '%',size = 8,transform = ax.transAxes)
ax.text(.06,0.58,mCT100_IC,size = 8,transform = ax.transAxes)
ax.text(.06,0.54,sCT100_IC,size = 8,transform = ax.transAxes)



ax.text(.06,0.86,'RT[100]',size = 8,transform = ax.transAxes)
#ax.text(.06,0.82,'Pulse Sampling Success ' + str(round(50*len(RT100_PW)/(50*PS_RT100),2)) + '%',size = 8,transform = ax.transAxes)
ax.text(.06,0.78,mRT100_PW,size = 8,transform = ax.transAxes)
ax.text(.06,0.74,sRT100_PW,size = 8,transform = ax.transAxes)
ax.text(.06,0.66,'CT[100]',size = 8,transform = ax.transAxes)
#ax.text(.06,0.62,'Pulse Sampling Success ' + str(round(50*len(CT100_PW)/(50*PS_CT100),2)) + '%',size = 8,transform = ax.transAxes)
ax.text(.06,0.58,mCT100_PW,size = 8,transform = ax.transAxes)
ax.text(.06,0.54,sCT100_PW,size = 8,transform = ax.transAxes)



ax3.text(.06,0.86,'RT[0]',size = 6,transform = ax3.transAxes)
#ax3.text(.06,0.82,'Pulse Sampling Success ' + str(round(50*len(RT0_PW)/(50*PS_RT0),2)) + '%',size = 6,transform = ax3.transAxes)
ax3.text(.06,0.78,mRT0_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.74,sRT0_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.66,'RT[5]',size = 6,transform = ax3.transAxes)
#ax3.text(.06,0.62,'Pulse Sampling Success ' + str(round(50*len(RT5_PW)/(50*PS_RT5),2)) + '%',size = 6,transform = ax3.transAxes)
ax3.text(.06,0.58,mRT5_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.54,sRT5_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.46,'RT[20]',size = 6,transform = ax3.transAxes)
#ax3.text(.06,0.42,'Pulse Sampling Success ' + str(round(50*len(RT20_PW)/(50*PS_RT20),2)) + '%',size = 6,transform = ax3.transAxes)
ax3.text(.06,0.38,mRT20_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.34,sRT20_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.26,'RT[100]',size = 6,transform = ax3.transAxes)
#ax3.text(.06,0.22,'Pulse Sampling Success ' + str(round(50*len(RT100_PW)/(50*PS_RT100),2)) + '%',size = 6,transform = ax3.transAxes)
ax3.text(.06,0.18,mRT100_PW,size = 6,transform = ax3.transAxes)
ax3.text(.06,0.14,sRT100_PW,size = 6,transform = ax3.transAxes)



ax4.text(.06,0.86,'RT[0]',size = 6,transform = ax4.transAxes)
#ax4.text(.06,0.82,'Pulse Sampling Success ' + str(round(50*len(RT0_IC)/(50*PS_RT0),2)) + '%',size = 6,transform = ax4.transAxes)
ax4.text(.06,0.78,mRT0_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.74,sRT0_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.66,'RT[5]',size = 6,transform = ax4.transAxes)
#ax4.text(.06,0.62,'Pulse Sampling Success ' + str(round(50*len(RT5_IC)/(50*PS_RT5),2)) + '%',size = 6,transform = ax4.transAxes)
ax4.text(.06,0.58,mRT5_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.54,sRT5_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.46,'RT[20]',size = 6,transform = ax4.transAxes)
#ax4.text(.06,0.42,'Pulse Sampling Success ' + str(round(50*len(RT20_IC)/(50*PS_RT20),2)) + '%',size = 6,transform = ax4.transAxes)
ax4.text(.06,0.38,mRT20_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.34,sRT20_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.26,'RT[20]',size = 6,transform = ax4.transAxes)
#ax4.text(.06,0.22,'Pulse Sampling Success ' + str(round(50*len(RT100_IC)/(50*PS_RT100),2)) + '%',size = 6,transform = ax4.transAxes)
ax4.text(.06,0.18,mRT100_IC,size = 6,transform = ax4.transAxes)
ax4.text(.06,0.14,sRT100_IC,size = 6,transform = ax4.transAxes)



ax.text(.06,0.86,'CT[5]',size = 6,transform = ax.transAxes)
#ax.text(.06,0.82,'Pulse Sampling Success ' + str(round(50*len(CT5_IC)/(50*PS_CT5),2)) + '%',size = 6,transform = ax.transAxes)
ax.text(.06,0.78,mCT5_IC,size = 6,transform = ax.transAxes)
ax.text(.06,0.74,sCT5_IC,size = 6,transform = ax.transAxes)
ax.text(.06,0.66,'CT[20]',size = 6,transform = ax.transAxes)
#ax.text(.06,0.62,'Pulse Sampling Success ' + str(round(50*len(CT20_IC)/(50*PS_CT20),2)) + '%',size = 6,transform = ax.transAxes)
ax.text(.06,0.58,mCT20_IC,size = 6,transform = ax.transAxes)
ax.text(.06,0.54,sCT20_IC,size = 6,transform = ax.transAxes)
ax.text(.06,0.46,'CT[100]',size = 6,transform = ax.transAxes)
#ax.text(.06,0.42,'Pulse Sampling Success ' + str(round(50*len(CT100_IC)/(50*PS_CT100),2)) + '%',size = 6,transform = ax.transAxes)
ax.text(.06,0.38,mCT100_IC,size = 6,transform = ax.transAxes)
ax.text(.06,0.34,sCT100_IC,size = 6,transform = ax.transAxes)




ax2.text(.06,0.86,'CT[5]',size = 6,transform = ax2.transAxes)
#ax2.text(.06,0.82,'Pulse Sampling Success ' + str(round(50*len(CT5_PW)/(50*PS_CT5),2)) + '%',size = 6,transform = ax2.transAxes)
ax2.text(.06,0.78,mCT5_PW,size = 6,transform = ax2.transAxes)
ax2.text(.06,0.74,sCT5_PW,size = 6,transform = ax2.transAxes)
ax2.text(.06,0.66,'CT[20]',size = 6,transform = ax2.transAxes)
#ax2.text(.06,0.62,'Pulse Sampling Success ' + str(round(50*len(CT20_PW)/(50*PS_CT20),2)) + '%',size = 6,transform = ax2.transAxes)
ax2.text(.06,0.58,mCT20_PW,size = 6,transform = ax2.transAxes)
ax2.text(.06,0.54,sCT20_PW,size = 6,transform = ax2.transAxes)
ax2.text(.06,0.46,'CT[20]',size = 6,transform = ax2.transAxes)
#ax2.text(.06,0.42,'Pulse Sampling Success ' + str(round(50*len(CT100_PW)/(50*PS_CT100),2)) + '%',size = 6,transform = ax2.transAxes)
ax2.text(.06,0.38,mCT100_PW,size = 6,transform = ax2.transAxes)
ax2.text(.06,0.34,sCT100_PW,size = 6,transform = ax2.transAxes)
'''
