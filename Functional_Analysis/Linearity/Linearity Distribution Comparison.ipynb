# %%
import scipy as sp
from scipy import stats
from scipy import integrate
from statistics import NormalDist
import numpy  as np
import matplotlib.pyplot as plt

# Number of Chips
chips = 100

# Load in Data
RT0_L = np.loadtxt('RT0_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
RT5_L = np.loadtxt('RT5_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
RT20_L = np.loadtxt('RT20_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
CT5_L = np.loadtxt('CT5_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
CT20_L = np.loadtxt('CT20_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)

print('done')
# Out:
# done

# %%
# StatistLs on the Distributions

# # # # # # # # RT[0]  # # # # # # # # # # 
print('\n############# RT[0] #############')
norm_RT0_L = NormalDist.from_samples(RT0_L)
mean_RT0_L = norm_RT0_L.mean; std_RT0_L = norm_RT0_L.stdev
mRT0_L = r'$\mu$' + ' = ' + str(round(mean_RT0_L,1))
sRT0_L = r'$\sigma$' + ' = ' + str(round(std_RT0_L,1))

print('Mean of L Distribution = ', round(mean_RT0_L,2))
print('Sigma of L Distribution = ', round(std_RT0_L,2))
print('3-Sigma = ',round(3*std_RT0_L,2),' [',round(mean_RT0_L - 3*std_RT0_L,2),
      ':',round(mean_RT0_L + 3*std_RT0_L,2), ']')
print('5-Sigma = ', round(5*std_RT0_L,2),' [',round(mean_RT0_L - 5*std_RT0_L,2),
      ':',round(mean_RT0_L + 5*std_RT0_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[5] # # # # # # # # # # 
print('\n############# RT[5] #############')
norm_RT5_L = NormalDist.from_samples(RT5_L)
mean_RT5_L = norm_RT5_L.mean; std_RT5_L = norm_RT5_L.stdev
mRT5_L = r'$\mu$' + ' = ' + str(round(mean_RT5_L,1))
sRT5_L = r'$\sigma$' + ' = ' + str(round(std_RT5_L,1))

print('Mean of L Distribution = ', round(mean_RT5_L,2))
print('Sigma of L Distribution = ', round(std_RT5_L,2))
print('3-Sigma = ',round(3*std_RT5_L,2),' [',round(mean_RT5_L - 3*std_RT5_L,2),
      ':',round(mean_RT5_L + 3*std_RT5_L,2), ']')
print('5-Sigma = ', round(5*std_RT5_L,2),' [',round(mean_RT5_L - 5*std_RT5_L,2),
      ':',round(mean_RT5_L + 5*std_RT5_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[20] # # # # # # # # # # 
print('\n############# RT[20] #############')
norm_RT20_L = NormalDist.from_samples(RT20_L)
mean_RT20_L = norm_RT20_L.mean; std_RT20_L = norm_RT20_L.stdev
mRT20_L = r'$\mu$' + ' = ' + str(round(mean_RT20_L,1))
sRT20_L = r'$\sigma$' + ' = ' + str(round(std_RT20_L,1))

print('Mean of L Distribution = ', round(mean_RT20_L,2))
print('Sigma of L Distribution = ', round(std_RT20_L,2))
print('3-Sigma = ',round(3*std_RT20_L,2),' [',round(mean_RT20_L - 3*std_RT20_L,2),
      ':',round(mean_RT20_L + 3*std_RT20_L,2), ']')
print('5-Sigma = ', round(5*std_RT20_L,2),' [',round(mean_RT20_L - 5*std_RT20_L,2),
      ':',round(mean_RT20_L + 5*std_RT20_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[5] # # # # # # # # # # 
print('\n############# CT[5] #############')
norm_CT5_L = NormalDist.from_samples(CT5_L)
mean_CT5_L = norm_CT5_L.mean; std_CT5_L = norm_CT5_L.stdev
mCT5_L = r'$\mu$' + ' = ' + str(round(mean_CT5_L,1))
sCT5_L = r'$\sigma$' + ' = ' + str(round(std_CT5_L,1))

print('Mean of L Distribution = ', round(mean_CT5_L,2))
print('Sigma of L Distribution = ', round(std_CT5_L,2))
print('3-Sigma = ',round(3*std_CT5_L,2),' [',round(mean_CT5_L - 3*std_CT5_L,2),
      ':',round(mean_CT5_L + 3*std_CT5_L,2), ']')
print('5-Sigma = ', round(5*std_CT5_L,2),' [',round(mean_CT5_L - 5*std_CT5_L,2),
      ':',round(mean_CT5_L + 5*std_CT5_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[20] # # # # # # # # # # 
print('\n############# CT[20] #############')
norm_CT20_L = NormalDist.from_samples(CT20_L)
mean_CT20_L = norm_CT20_L.mean; std_CT20_L = norm_CT20_L.stdev
mCT20_L = r'$\mu$' + ' = ' + str(round(mean_CT20_L,1))
sCT20_L = r'$\sigma$' + ' = ' + str(round(std_CT20_L,1))

print('Mean of L Distribution = ', round(mean_CT20_L,2))
print('Sigma of L Distribution = ', round(std_CT20_L,2))
print('3-Sigma = ',round(3*std_CT20_L,2),' [',round(mean_CT20_L - 3*std_CT20_L,2),
      ':',round(mean_CT20_L + 3*std_CT20_L,2), ']')
print('5-Sigma = ', round(5*std_CT20_L,2),' [',round(mean_CT20_L - 5*std_CT20_L,2),
      ':',round(mean_CT20_L + 5*std_CT20_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################


print('\ndone')
# Out:
# ############# RT[0] #############
# Mean of L Distribution =  406.53
# Sigma of L Distribution =  2.34
# 3-Sigma =  7.02  [ 399.51 : 413.54 ]
# 5-Sigma =  11.7  [ 394.83 : 418.22 ]
#
# ############# RT[5] #############
# Mean of L Distribution =  406.5
# Sigma of L Distribution =  2.54
# 3-Sigma =  7.62  [ 398.88 : 414.12 ]
# 5-Sigma =  12.7  [ 393.8 : 419.2 ]
#
# ############# RT[20] #############
# Mean of L Distribution =  406.58
# Sigma of L Distribution =  2.63
# 3-Sigma =  7.9  [ 398.68 : 414.47 ]
# 5-Sigma =  13.16  [ 393.42 : 419.74 ]
#
# ############# CT[5] #############
# Mean of L Distribution =  401.49
# Sigma of L Distribution =  5.6
# 3-Sigma =  16.8  [ 384.69 : 418.29 ]
# 5-Sigma =  28.0  [ 373.5 : 429.49 ]
#
# ############# CT[20] #############
# Mean of L Distribution =  401.82
# Sigma of L Distribution =  6.39
# 3-Sigma =  19.18  [ 382.63 : 421.0 ]
# 5-Sigma =  31.97  [ 369.84 : 433.79 ]
#
# done

# %%
##########################################################

# Comparison between RT[20] and CT[20] for Linearity
fig, ax = plt.subplots()
ax.set_title('Linearity RT[20] and CT[20] Distributions | 200mV BL',
            fontdict = {'fontsize' : 10})
ax.set_xlabel('Least Square Fit Linear Coefficient Value [adc/Subrun]', loc = 'right')
c = max(RT20_L)-min(RT20_L); d = max(CT20_L)-min(CT20_L); ratio = d/c
binsRT20L = 60; binsCT20L = int(binsRT20L*ratio)
ax.hist(RT20_L, bins = binsRT20L, histtype = 'step', hatch = '...', stacked = False,
        color = 'tab:red', linewidth = 1.5, label = 'RT[5] Linearity Distribution')
ax.hist(CT20_L, bins = binsCT20L, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'tab:blue', linewidth = 1.5, label = 'CT[5] Linearity Distribution')
plt.xlim([325,450])
# Labeling Mean, sigma on plot
ax.text(.06,0.86,'RT[20]',size = 8,transform = ax.transAxes)
ax.text(.06,0.82,mRT20_L,size = 8,transform = ax.transAxes)
ax.text(.06,0.78,sRT20_L,size = 8,transform = ax.transAxes)

ax.text(.06,0.72,'CT[20]',size = 8,transform = ax.transAxes)
ax.text(.06,0.68,mCT20_L,size = 8,transform = ax.transAxes)
ax.text(.06,0.64,sCT20_L,size = 8,transform = ax.transAxes)

ax.text(.06,0.58,'RT[20]: ' + str(round(16*chips - len(RT20_L))) + ' outlier channels',size = 8,transform = ax.transAxes)
ax.text(.06,0.54,'CT[20]: ' + str(round(16*chips - len(CT20_L))) + ' outlier channels',size = 8,transform = ax.transAxes)
ax.text(.06,0.48,'*Note: outlier outside of [350:450] range',size = 6,transform = ax.transAxes)

plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path1 = '../../../../Linearity RT CT [20].png'
plt.savefig(path1,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')

plt.show()

##########################################################

print('\ndone')
# Out:
# done

# %% [markdown]
# ### Normalized Linearity

# %%
# Number of Chips
chips = 100

# Load in Data
RT0_L = np.loadtxt('RT0_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
RT5_L = np.loadtxt('RT5_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
RT20_L = np.loadtxt('RT20_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
CT5_L = np.loadtxt('CT5_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)
CT20_L = np.loadtxt('CT20_Linearity_Histogram_Data.dat', dtype = float, delimiter = None)

'''
Mean of RT[0] Distribution: 406.53
'''
Normalized_Mean = 406.53
plus_10 = 406.53 + 406.53*.1
minus_10 = 406.53 - 406.53*.1


# Normalization

the_list = [RT0_L, RT5_L, RT20_L, CT5_L, CT20_L]

for x in the_list:
    for i in range(len(x)):
        x[i] = x[i]/Normalized_Mean
        
print('done')
# Out:
# done

# %%
# StatistLs on the Normalized Distributions

# # # # # # # # RT[0]  # # # # # # # # # # 
print('\n############# RT[0] #############')
norm_RT0_L = NormalDist.from_samples(RT0_L)
mean_RT0_L = norm_RT0_L.mean; std_RT0_L = norm_RT0_L.stdev
mRT0_L = r'$\mu$' + ' = ' + str(round(mean_RT0_L,2))
sRT0_L = r'$\sigma$' + ' = ' + str(round(std_RT0_L,2))

print('Mean of L Distribution = ', round(mean_RT0_L,2))
print('Sigma of L Distribution = ', round(std_RT0_L,2))
print('3-Sigma = ',round(3*std_RT0_L,2),' [',round(mean_RT0_L - 3*std_RT0_L,2),
      ':',round(mean_RT0_L + 3*std_RT0_L,2), ']')
print('5-Sigma = ', round(5*std_RT0_L,2),' [',round(mean_RT0_L - 5*std_RT0_L,2),
      ':',round(mean_RT0_L + 5*std_RT0_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[5] # # # # # # # # # # 
print('\n############# RT[5] #############')
norm_RT5_L = NormalDist.from_samples(RT5_L)
mean_RT5_L = norm_RT5_L.mean; std_RT5_L = norm_RT5_L.stdev
mRT5_L = r'$\mu$' + ' = ' + str(round(mean_RT5_L,2))
sRT5_L = r'$\sigma$' + ' = ' + str(round(std_RT5_L,2))

print('Mean of L Distribution = ', round(mean_RT5_L,2))
print('Sigma of L Distribution = ', round(std_RT5_L,2))
print('3-Sigma = ',round(3*std_RT5_L,2),' [',round(mean_RT5_L - 3*std_RT5_L,2),
      ':',round(mean_RT5_L + 3*std_RT5_L,2), ']')
print('5-Sigma = ', round(5*std_RT5_L,2),' [',round(mean_RT5_L - 5*std_RT5_L,2),
      ':',round(mean_RT5_L + 5*std_RT5_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # RT[20] # # # # # # # # # # 
print('\n############# RT[20] #############')
norm_RT20_L = NormalDist.from_samples(RT20_L)
mean_RT20_L = norm_RT20_L.mean; std_RT20_L = norm_RT20_L.stdev
mRT20_L = r'$\mu$' + ' = ' + str(round(mean_RT20_L,2))
sRT20_L = r'$\sigma$' + ' = ' + str(round(std_RT20_L,2))

print('Mean of L Distribution = ', round(mean_RT20_L,2))
print('Sigma of L Distribution = ', round(std_RT20_L,2))
print('3-Sigma = ',round(3*std_RT20_L,2),' [',round(mean_RT20_L - 3*std_RT20_L,2),
      ':',round(mean_RT20_L + 3*std_RT20_L,2), ']')
print('5-Sigma = ', round(5*std_RT20_L,2),' [',round(mean_RT20_L - 5*std_RT20_L,2),
      ':',round(mean_RT20_L + 5*std_RT20_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[5] # # # # # # # # # # 
print('\n############# CT[5] #############')
norm_CT5_L = NormalDist.from_samples(CT5_L)
mean_CT5_L = norm_CT5_L.mean; std_CT5_L = norm_CT5_L.stdev
mCT5_L = r'$\mu$' + ' = ' + str(round(mean_CT5_L,2))
sCT5_L = r'$\sigma$' + ' = ' + str(round(std_CT5_L,2))

print('Mean of L Distribution = ', round(mean_CT5_L,2))
print('Sigma of L Distribution = ', round(std_CT5_L,2))
print('3-Sigma = ',round(3*std_CT5_L,2),' [',round(mean_CT5_L - 3*std_CT5_L,2),
      ':',round(mean_CT5_L + 3*std_CT5_L,2), ']')
print('5-Sigma = ', round(5*std_CT5_L,2),' [',round(mean_CT5_L - 5*std_CT5_L,2),
      ':',round(mean_CT5_L + 5*std_CT5_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################

# # # # # # # # CT[20] # # # # # # # # # # 
print('\n############# CT[20] #############')
norm_CT20_L = NormalDist.from_samples(CT20_L)
mean_CT20_L = norm_CT20_L.mean; std_CT20_L = norm_CT20_L.stdev
mCT20_L = r'$\mu$' + ' = ' + str(round(mean_CT20_L,2))
sCT20_L = r'$\sigma$' + ' = ' + str(round(std_CT20_L,2))

print('Mean of L Distribution = ', round(mean_CT20_L,2))
print('Sigma of L Distribution = ', round(std_CT20_L,2))
print('3-Sigma = ',round(3*std_CT20_L,2),' [',round(mean_CT20_L - 3*std_CT20_L,2),
      ':',round(mean_CT20_L + 3*std_CT20_L,2), ']')
print('5-Sigma = ', round(5*std_CT20_L,2),' [',round(mean_CT20_L - 5*std_CT20_L,2),
      ':',round(mean_CT20_L + 5*std_CT20_L,2), ']')

# # # # # # # # # # # # # # # # # # # # # # # # # #

###################################################


print('\ndone')
# Out:
# ############# RT[0] #############
# Mean of L Distribution =  1.0
# Sigma of L Distribution =  0.01
# 3-Sigma =  0.02  [ 0.98 : 1.02 ]
# 5-Sigma =  0.03  [ 0.97 : 1.03 ]
#
# ############# RT[5] #############
# Mean of L Distribution =  1.0
# Sigma of L Distribution =  0.01
# 3-Sigma =  0.02  [ 0.98 : 1.02 ]
# 5-Sigma =  0.03  [ 0.97 : 1.03 ]
#
# ############# RT[20] #############
# Mean of L Distribution =  1.0
# Sigma of L Distribution =  0.01
# 3-Sigma =  0.02  [ 0.98 : 1.02 ]
# 5-Sigma =  0.03  [ 0.97 : 1.03 ]
#
# ############# CT[5] #############
# Mean of L Distribution =  0.99
# Sigma of L Distribution =  0.01
# 3-Sigma =  0.04  [ 0.95 : 1.03 ]
# 5-Sigma =  0.07  [ 0.92 : 1.06 ]
#
# ############# CT[20] #############
# Mean of L Distribution =  0.99
# Sigma of L Distribution =  0.02
# 3-Sigma =  0.05  [ 0.94 : 1.04 ]
# 5-Sigma =  0.08  [ 0.91 : 1.07 ]
#
# done

# %%
fig, ax = plt.subplots()
ax.set_title('Linearity RT[20] and CT[20] Distributions | 200mV BL',
            fontdict = {'fontsize' : 10})
ax.set_xlabel('Linearity', loc = 'right')
c = max(RT20_L)-min(RT20_L); d = max(CT20_L)-min(CT20_L); ratio = d/c
binsRT20L = 60; binsCT20L = int(binsRT20L*ratio)
ax.hist(RT20_L, bins = binsRT20L, histtype = 'step', hatch = '...', stacked = False,
        color = 'tab:red', linewidth = 1.5, label = 'RT[5] Linearity Distribution')
ax.hist(CT20_L, bins = binsCT20L, histtype = 'step', hatch = 'xxx', stacked = False,
        color = 'tab:blue', linewidth = 1.5, label = 'CT[5] Linearity Distribution')
plt.xlim([0.80,1.11])
# Labeling Mean, sigma on plot
ax.text(.06,0.86,'RT[20]',size = 8,transform = ax.transAxes)
ax.text(.06,0.82,mRT20_L,size = 8,transform = ax.transAxes)
ax.text(.06,0.78,sRT20_L,size = 8,transform = ax.transAxes)

ax.text(.06,0.72,'CT[20]',size = 8,transform = ax.transAxes)
ax.text(.06,0.68,mCT20_L,size = 8,transform = ax.transAxes)
ax.text(.06,0.64,sCT20_L,size = 8,transform = ax.transAxes)

ax.text(.06,0.58,'RT[20]: ' + str(round(16*chips - len(RT20_L))) + ' outlier channels',size = 8,transform = ax.transAxes)
ax.text(.06,0.54,'CT[20]: ' + str(round(16*chips - len(CT20_L))) + ' outlier channels',size = 8,transform = ax.transAxes)
ax.text(.06,0.48,'*Note: outliers ' + u"\u00B1" + '10% of RT[0] Linearity',size = 6,transform = ax.transAxes)

plt.legend(shadow=True, loc = 'upper right', prop={'size': 6})
path1 = '../../../../Normalized Linearity RT CT [20].png'
plt.savefig(path1,dpi=300, bbox_inches='tight', pad_inches=.3,facecolor = 'w')

plt.show()

##########################################################

print('\ndone')
# Out:
# done
